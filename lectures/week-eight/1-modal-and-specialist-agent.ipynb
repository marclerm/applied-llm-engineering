# %% [markdown]
# # "THE PRICE IS RIGHT" — Week 8, Day 1
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.
#
# # The Price is Right
#
# ## Week 8 Order of Play
#
# Day 1: Modal.com and the Specialist Agent
# Day 2: RAG, FrontierAgent, Ensemble Agent
# Day 3: ScannerAgent, MessengerAgent
# Day 4: AutonomousPlannerAgent and DealAgentFramework
# Day 5: The Price Is Right Finale

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#b22;">Especially important this week: pull the latest</h2>
#             <span style="color:#b22;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             Please see Guide 3 in the Guides folder if you're not sure how to do a <code>git pull</code>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import locale
from dotenv import find_dotenv, load_dotenv

# Locate the repository-level .env whether Jupyter starts here or at the repo root.
dotenv_path = find_dotenv(usecwd=True)
if not dotenv_path:
    raise FileNotFoundError("Could not find the repository .env file")
load_dotenv(dotenv_path, override=True)

required_keys = ("MODAL_TOKEN_ID", "MODAL_TOKEN_SECRET", "OPENAI_API_KEY")
missing_keys = [key for key in required_keys if not os.getenv(key)]
if missing_keys:
    raise RuntimeError(f"Missing required environment variables: {', '.join(missing_keys)}")

# Import API clients only after credentials and model configuration are loaded.
import modal
from agents.preprocessor import Preprocessor

# %%
# To check that your computer can output special characters, make sure this outputs UTF-8 

print(locale.getpreferredencoding())  # Should print 'UTF-8'
# Out:
# UTF-8

# %%
os.environ["PYTHONIOENCODING"] = "utf-8"

# %% [markdown]
# # Setting up the modal tokens
#
# ## IMPORTANT - please do read and follow these instructions!
#
# First please visit: https://modal.com
#
# And sign up for an account. Then click the Avatar menu on the top right and select "Settings"
#
# Then click "API Tokens" in the left sidebar, then click "New Token".
#
# You will be given something like this to run:
#
# `modal token set --token-id ak-somethinghere --token-secret as-somethinghere`
#
# If you are using `uv`, the equivalent command is:
#
# `uv run modal token set --token-id ak-somethinghere --token-secret as-somethinghere`
#
# ### Troubleshooting
#
# If you have problems, 3 things to try:
#
# 1. Try running `modal token new` before `modal token set..` (or prefix both with `uv run` if you use uv).
#
# 2. Suggestion from student David S. on Windows:
#
# > In case anyone else using Windows hits this problem: Along with having to run `modal token new` from a command prompt, you have to move the generated token file. It will deploy the token file (.modal.toml) to your Windows profile folder. The virtual environment couldn't see that location (strangely, it couldn't even after I set environment variables for it and rebooted). I moved that token file to the folder I'm operating out of for the lab and it stopped throwing auth errors.
#
# 3. Doing in the manual way:
#
# It might be totally fine to simply add the 2 keys directly to your .env file:
#
# ```
# MODAL_TOKEN_ID=ak-...
# MODAL_TOKEN_SECRET=as-...
# ```
#
# Then restart the notebook kernel and rerun the setup cell to load these environment variables.

# %%
from hello import app, hello, hello_europe

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# /Users/marcolerma/GitHub/applied-llm-engineering/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 'Hello from Atlanta, Georgia, US!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Boydton, Virginia, US!!'

# %% [markdown]
# ## Added thanks to student Tue H.
#
# If you look in hello.py, I've added a simple function hello_europe
#
# That uses the decorator:
# `@app.function(image=image, region="eu")`
#
# See the result below! More region specific settings are [here](https://modal.com/docs/guide/region-selection)
#
# Note that it does consume marginally more credits to specify a region.

# %%
with app.run():
    reply=hello_europe.remote()
reply

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# ## Super important - please read - this confuses a lot of people!
#
# Secrets in Modal are given a **name** that describes the secret.
# Then the secret itself has a KEY and a VALUE.
# We will be setting up a secret with:
#
# Name: huggingface-secret
# Key: HF_TOKEN
# Value: hf_...
#
# ## The bulletproof recipe:
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **huggingface-secret** because that's how we refer to it in the code
# 4. Fill in your key as HF_TOKEN and the value as your actual token hf_...
# 5. Click done
#
# ### And now back to business: time to work with Llama

# %%
# This import may give a deprecation warning about adding local Python modules to the Image
# That warning can be safely ignored. You may get the same warning in other places, too..

from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Never gonna give you up, never gonna")
result

# Or it you object to being rickrolled, try this: "Hey Jude, don't make it"

# %%
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# ✓ Initialized. View run at
# https://modal.com/apps/marcolerma-1312/main/ap-T6vVsFIPaOKB9qzZ26Im4v
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# ├── 🔨 Created mount
# │   /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# │   ephemeral.py
# └── 🔨 Created function price.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# │   ephemeral.py
# └── 🔨 Created function price.
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at Im4v
# ⠙ Worker assigned... View app at Im4v
# ⠼ Worker assigned... View app at Im4v
# ⠧ Worker assigned... View app at Im4v
# ⠋ Worker assigned... View app at Im4v
# ⠸ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ://modal.com/apps/marcolerma-1312/main/ap-T6vVsFIPaOKB9qzZ26Im4v
# ⠙ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# ⠸ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# Fetching 2 files:  50%|█████     | 1/2 [00:17<00:17, 17.81s/it]
# Fetching 2 files: 100%|██████████| 2/2 [00:27<00:00, 13.87s/it]ew app at https://modal.com/apps/marcoler
# Fetching 2 files: 100%|██████████| 2/2 [00:27<00:00, 13.87s/it]ew app at https://modal.com/apps/marcoler
# ⠇ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ://modal.com/apps/marcolerma-1312/main/ap-T6vVsFIPaOKB9qzZ26Im4v
# ⠇ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at it/s]⠹ Running (1/1 containers active)... View app at https://modal.com/apps/marcoler
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ://modal.com/apps/marcolerma-1312/main/ap-T6vVsFIPaOKB9qzZ26Im4v
# ⠴ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# Loading checkpoint shards:  50%|█████     | 1/2 [00:05<00:05,  5.43s/it]
# Loading checkpoint shards: 100%|██████████| 2/2 [00:06<00:00,  3.07s/it] https://modal.com/apps/marcoler
# Loading checkpoint shards: 100%|██████████| 2/2 [00:06<00:00,  3.43s/it] https://modal.com/apps/marcoler
# /usr/local/lib/python3.9/site-packages/peft/config.py:165: UserWarning: Unexpected keyword arguments ['alora_invocation_tokens', 'arrow_config', 'ensure_weight_tying', 'peft_version'] for class LoraConfig, these are ignored. This probably means that you're loading a configuration file that was saved using a higher version of the library and additional parameters have been introduced since. It is highly recommended to upgrade the PEFT version before continuing (e.g. by running `pip install -U peft`).
#   warnings.warn(
# ⠼ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.p at https://modal.com/apps/marcoler
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ⠼ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# https://modal.com/apps/marcolerma-1312/main/ap-T6vVsFIPaOKB9qzZ26Im4v
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/marcolerma-1312/main/ap-T6vVsFIPaOKB9qzZ26Im4v
# 90.0

# %%
# Uses PRICER_PREPROCESSOR_MODEL from .env (openai/gpt-5-nano).
preprocessor = Preprocessor()
print(f"Preprocessor model: {preprocessor.model_name}")
text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(text)
# Out:
# Preprocessor model: openai/gpt-5-nano
# Title: HyperX QuadCast USB-C Condenser Microphone
# Category: Electronics
# Brand: HyperX
# Description: HyperX QuadCast USB-C condenser microphone designed to deliver crystal-clear audio for computer recording.
# Details: Features USB-C plug-and-play connectivity, four selectable polar patterns (stereo, cardioid, omnidirectional, bidirectional), built-in pop filter, and a mute button with LED indicator.

# %%
# Optional: explicitly override the model instead of relying on .env.
preprocessor = Preprocessor(model_name="openai/gpt-5-nano")
text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(text)
# Out:
# Title: HyperX QuadCast USB-C Condenser Microphone
# Category: Electronics
# Brand: HyperX
# Description: USB-C condenser microphone delivering crystal-clear audio for streams, podcasts, and calls.
# Details: Features include four polar patterns, gain control, headphone monitoring, and USB-C connectivity.

# %% [markdown]
# ### OpenAI preprocessor configuration
#
# Add these entries to the repository `.env` file (never commit the real API key):
#
# ```env
# OPENAI_API_KEY=sk-...
# PRICER_PREPROCESSOR_MODEL=openai/gpt-5-nano
# ```
#
# After changing `.env`, restart the notebook kernel and rerun the setup cell so the new values are loaded.

# %%
with modal.enable_output():
    with app.run():
        result = price.remote(text)
print(result)
# Out:
# ✓ Initialized. View run at
# https://modal.com/apps/marcolerma-1312/main/ap-37mno0IbcOOWHZjI5YXkdh
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# ├── 🔨 Created mount
# │   /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# │   ephemeral.py
# └── 🔨 Created function price.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# │   ephemeral.py
# └── 🔨 Created function price.
# ⠇ Worker assigned... View app at
# ⠹ Worker assigned... View app at Xkdh
# ⠴ Worker assigned... View app at Xkdh
# ⠇ Worker assigned... View app at Xkdh
# ⠙ Worker assigned... View app at Xkdh
# ⠼ Worker assigned... View app at Xkdh
# ⠇ Worker assigned... View app at Xkdh
# ⠙ Worker assigned... View app at Xkdh
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ://modal.com/apps/marcolerma-1312/main/ap-37mno0IbcOOWHZjI5YXkdh
# ⠼ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# ⠇ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# Fetching 2 files:  50%|█████     | 1/2 [00:12<00:12, 12.23s/it]
# ⠸ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# Fetching 2 files: 100%|██████████| 2/2 [00:23<00:00, 11.60s/it]
# Fetching 2 files: 100%|██████████| 2/2 [00:23<00:00, 11.60s/it]ew app at https://modal.com/apps/marcoler
# ⠦ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠋ Running (1/1 containers active)... View app at
# ://modal.com/apps/marcolerma-1312/main/ap-37mno0IbcOOWHZjI5YXkdh
# ⠸ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ⠇ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠙ Running (1/1 containers active)... View app at 4,  4.44s/it]⠋ Running (1/1 containers active)... View app at https://modal.com/apps/marcoler
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ://modal.com/apps/marcolerma-1312/main/ap-37mno0IbcOOWHZjI5YXkdh
# Loading checkpoint shards: 100%|██████████| 2/2 [00:05<00:00,  2.65s/it] https://modal.com/apps/marcoler
# Loading checkpoint shards: 100%|██████████| 2/2 [00:05<00:00,  2.92s/it] https://modal.com/apps/marcoler
# ⠧ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠋ Running (1/1 containers active)... View app at
# /usr/local/lib/python3.9/site-packages/peft/config.py:165: UserWarning: Unexpected keyword arguments ['alora_invocation_tokens', 'arrow_config', 'ensure_weight_tying', 'peft_version'] for class LoraConfig, these are ignored. This probably means that you're loading a configuration file that was saved using a higher version of the library and additional parameters have been introduced since. It is highly recommended to upgrade the PEFT version before continuing (e.g. by running `pip install -U peft`).
#   warnings.warn(
# ⠸ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ⠇ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ⠙ Running (1/1 containers active)... View app at ew app at https://modal.com/apps/marcoler
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# https://modal.com/apps/marcolerma-1312/main/ap-37mno0IbcOOWHZjI5YXkdh
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/marcolerma-1312/main/ap-37mno0IbcOOWHZjI5YXkdh
# 110.0

# %%
print(text)
# Out:
# Title: HyperX QuadCast USB-C Condenser Microphone
# Category: Electronics
# Brand: HyperX
# Description: USB-C condenser microphone delivering crystal-clear audio for streams, podcasts, and calls.
# Details: Features include four polar patterns, gain control, headphone monitoring, and USB-C connectivity.

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `modal deploy -m module_name` will deploy your code as a Deployed App. If you use uv, prefix the command with `uv run`.
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note about secrets
#
# In both the files `pricer_service.py` and `pricer_service2.py` you will find code like this near the top:
# `secrets = [modal.Secret.from_name("hf-secret")]`
# You may need to change from `hf-secret` to `huggingface-secret` depending on how the Secret is configured in modal.
# To check, visit this page and look in the first column:
# https://modal.com/secrets/
#
# ## Important note for Windows people:
#
# On the next line, I call `modal deploy` from within JupyterLab; I've heard that on some versions of Windows this gives a strange unicode error because Modal prints emojis to the output which can't be displayed. If that happens to you, open a Terminal and run the same `modal deploy` command there.

# %%
# You can also run "modal deploy -m pricer_service" in the Terminal

# !modal deploy -m pricer_service

# %%
pricer = modal.Function.from_name("pricer-service", "price")

# %% [markdown]
# Watch it happening:
#
# https://modal.com

# %%
# This can take a while! We'll use faster approaches shortly

pricer.remote(text)
# Out:
# 110.0

# %%
# You can also run "modal deploy -m pricer_service2" at the command line in an activated environment

# !modal deploy -m pricer_service2
# Out:
# ⠸ Creating objects.....
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Building image im-4A3eK4IC2ndUPHj2eRW2Aj
# ⠋ Creating objects...
# m🔨 Created mount /Users/marcolerma/GitHub/applied-llm-engineering/lectures/w
# => Step 0: FROM base
# ⠋ Creating objects...
# m🔨 Created mount /Users/marcolerma/GitHub/applied-llm-engineering/lectures/w
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# ⠋ Creating objects...
# ⠹ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# ⠹ Creating objects...
# Collecting acceleratemarcolerma/GitHub/applied-llm-engineering/lectures/w
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# ⠹ Creating objects...
# ⠹ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting bitsandbytes
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# ⠹ Creating objects...
# Collecting huggingfacearcolerma/GitHub/applied-llm-engineering/lectures/w
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# ⠹ Creating objects...
# ⠴ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting peft
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.17.1-py3-none-any.whl.metadata (14 kB)
# ⠴ Creating objects...
# Collecting torchsers/marcolerma/GitHub/applied-llm-engineering/lectures/w
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (30 kB)
# ⠴ Creating objects...
# Collecting transformersrcolerma/GitHub/applied-llm-engineering/lectures/w
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# ⠴ Creating objects...
# ⠇ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ⠹ Creating objects...
# Collecting packaging>=20.0 (from accelerate)ed-llm-engineering/lectures/w
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-26.3-py3-none-any.whl.metadata (3.5 kB)
# ⠹ Creating objects...
# Collecting psutil (from accelerate)Hub/applied-llm-engineering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# ⠸ Creating objects...
# Collecting pyyaml (from accelerate)Hub/applied-llm-engineering/lectures/w
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/pyyaml-6.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# ⠼ Creating objects...
# ⠴ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting huggingface_hub>=0.21.0 (from accelerate)
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# ⠦ Creating objects...
# Collecting safetensors>=0.4.3 (from accelerate)llm-engineering/lectures/w
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# ⠇ Creating objects...
# Collecting filelock (from torch)GitHub/applied-llm-engineering/lectures/w
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# ⠇ Creating objects...
# Collecting typing-extensions>=4.10.0 (from torch)m-engineering/lectures/w
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/typing-extensions/typing_extensions-4.16.0-py3-none-any.whl.metadata (3.3 kB)
# ⠇ Creating objects...
# ⠇ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting sympy>=1.13.3 (from torch)
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ⠏ Creating objects...
# Collecting networkx (from torch)GitHub/applied-llm-engineering/lectures/w
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# ⠏ Creating objects...
# Collecting jinja2 (from torch)a/GitHub/applied-llm-engineering/lectures/w
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ⠏ Creating objects...
# Collecting fsspec (from torch)a/GitHub/applied-llm-engineering/lectures/w
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# ⠏ Creating objects...
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)neering/lectures/w
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ⠏ Creating objects...
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)ering/lectures/w
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ⠏ Creating objects...
# ⠙ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ⠸ Creating objects...
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)ngineering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# ⠸ Creating objects...
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)ngineering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# ⠸ Creating objects...
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)ngineering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ⠸ Creating objects...
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)gineering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# ⠸ Creating objects...
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)neering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# ⠸ Creating objects...
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)neering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# ⠸ Creating objects...
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)gineering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# ⠸ Creating objects...
# Collecting nvidia-nccl-cu12==2.27.3 (from torch)lm-engineering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# ⠸ Creating objects...
# ⠼ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# ⠧ Creating objects...
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)ineering/lectures/w
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ⠇ Creating objects...
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)ngineering/lectures/w
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ⠇ Creating objects...
# Collecting triton==3.4.0 (from torch)b/applied-llm-engineering/lectures/w
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.4.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# ⠇ Creating objects...
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.9/site-packages (from triton==3.4.0->torch) (58.1.0)
# ⠇ Creating objects...
# Collecting importlib-metadata (from triton==3.4.0->torch)ering/lectures/w
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/importlib-metadata/importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# ⠇ Creating objects...
# Collecting tqdm (from peft)erma/GitHub/applied-llm-engineering/lectures/w
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# ⠇ Creating objects...
# ⠇ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting huggingface_hub>=0.21.0 (from accelerate)
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ⠇ Creating objects...
# ⠙ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting regex!=2019.12.17 (from transformers)
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2026.1.15-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# ⠸ Creating objects...
# Collecting requests (from transformers)applied-llm-engineering/lectures/w
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ⠸ Creating objects...
# ⠼ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# ⠼ Creating objects...
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface_hub>=0.21.0->accelerate)
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.6.0-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# ⠼ Creating objects...
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)ering/lectures/w
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ⠼ Creating objects...
# Collecting zipp>=3.20 (from importlib-metadata->triton==3.4.0->torch)es/w
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/zipp/zipp-3.23.1-py3-none-any.whl.metadata (3.6 kB)
# ⠴ Creating objects...
# Collecting MarkupSafe>=2.0 (from jinja2->torch)llm-engineering/lectures/w
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/markupsafe-3.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# ⠦ Creating objects...
# ⠧ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Collecting charset_normalizer<4,>=2 (from requests->transformers)
# ⠇ Creating objects...
# ⠋ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.5.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (45 kB)
# ⠙ Creating objects...
# Collecting idna<4,>=2.5 (from requests->transformers)gineering/lectures/w
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/idna/idna-3.19-py3-none-any.whl.metadata (9.2 kB)
# ⠙ Creating objects...
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)ing/lectures/w
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# ⠙ Creating objects...
# Collecting certifi>=2017.4.17 (from requests->transformers)ing/lectures/w
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/certifi/certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.10.1-py3-none-any.whl (374 kB)
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
# ⠹ Creating objects...
# ⠼ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 52.5 MB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl (59.4 MB)
# ⠦ Creating objects...
# ⠧ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# ⠸ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 106.0 MB/s eta 0:00:00
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl (888.0 MB)
# ⠸ Creating objects...
# ⠦ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# ⠙ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.0/888.0 MB 228.8 MB/s eta 0:00:00
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# ⠹ Creating objects...
# ⠼ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 543.0 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# ⠼ Creating objects...
# ⠼ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 571.4 MB/s eta 0:00:00
# ⠼ Creating objects...
# ⠼ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# ⠼ Creating objects...
# ⠦ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
# ⠧ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 554.2 MB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# ⠇ Creating objects...
# ⠇ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 1.3 GB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# ⠇ Creating objects...
# ⠋ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# ⠸ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 535.2 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# ⠼ Creating objects...
# ⠦ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
# ⠦ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 545.7 MB/s eta 0:00:00
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# ⠧ Creating objects...
# ⠧ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 857.1 MB/s eta 0:00:00
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# ⠧ Creating objects...
# ⠇ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 561.4 MB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# ⠇ Creating objects...
# ⠋ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 549.0 MB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# ⠦ Creating objects...
# ⠦ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 534.5 MB/s eta 0:00:00
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# ⠹ Creating objects...
# ⠹ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 537.5 MB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
# ⠇ Creating objects...
# ⠏ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 213.7 MB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# ⠇ Creating objects...
# ⠇ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 569.6 MB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.4.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
# ⠇ Creating objects...
# ⠙ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# ⠧ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 MB 218.5 MB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.17.1-py3-none-any.whl (504 kB)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.57.6-py3-none-any.whl (12.0 MB)
# ⠇ Creating objects...
# ⠋ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 234.6 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# ⠼ Creating objects...
# ⠼ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 833.2 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.6.0-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
# ⠼ Creating objects...
# ⠼ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 609.1 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# ⠼ Creating objects...
# ⠼ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 590.9 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.10.0-py3-none-any.whl (200 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-26.3-py3-none-any.whl (129 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/pyyaml-6.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (750 kB)
# ⠼ Creating objects...
# ⠼ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 456.3 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2026.1.15-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (791 kB)
# ⠼ Creating objects...
# ⠼ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 791.3/791.3 kB 213.5 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# ⠼ Creating objects...
# ⠼ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 573.5 MB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# ⠦ Creating objects...
# ⠦ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.1 GB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.70.0-py3-none-any.whl (80 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/typing-extensions/typing_extensions-4.16.0-py3-none-any.whl (45 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.19.1-py3-none-any.whl (15 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/importlib-metadata/importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/zipp/zipp-3.23.1-py3-none-any.whl (10 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/markupsafe-3.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.2.1-py3-none-any.whl (1.6 MB)
# ⠦ Creating objects...
# ⠦ Creating objects...a/GitHub/applied-llm-engineering/lectures/w
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 423.7 MB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.5-py3-none-any.whl (64 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.5.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (262 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/idna/idna-3.19-py3-none-any.whl (68 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.6.3-py3-none-any.whl (131 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/certifi/certifi-2026.7.22-py3-none-any.whl (136 kB)
# ⠦ Creating objects...
# ⠧ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, huggingface, zipp, urllib3, typing-extensions, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, idna, hf-xet, fsspec, filelock, charset_normalizer, certifi, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, importlib-metadata, triton, nvidia-cusolver-cu12, huggingface_hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# ⠙ Creating objects...
# ⠹ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
# ...
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#
# ⠼ Creating objects...
# Successfully installed MarkupSafe-3.0.3 accelerate-1.10.1 bitsandbytes-0.48.2 certifi-2026.7.22 charset_normalizer-3.5.1 filelock-3.19.1 fsspec-2025.10.0 hf-xet-1.6.0 huggingface-0.0.1 huggingface_hub-0.36.2 idna-3.19 importlib-metadata-8.7.1 jinja2-3.1.6 mpmath-1.3.0 networkx-3.2.1 numpy-2.0.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 packaging-26.3 peft-0.17.1 psutil-7.2.2 pyyaml-6.0.3 regex-2026.1.15 requests-2.32.5 safetensors-0.7.0 sympy-1.14.0 tokenizers-0.22.2 torch-2.8.0 tqdm-4.70.0 transformers-4.57.6 triton-3.4.0 typing-extensions-4.16.0 urllib3-2.6.3 zipp-3.23.1
# ⠼ Creating objects...
# m🔨 Created mount /Users/marcolerma/GitHub/applied-llm-engineering/lectures/w
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ⠼ Creating objects...
# ⠴ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Saving image...
# ⠇ Creating objects...
# ⠙ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Uploading image snapshot… ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/7.1 GB 0:00:00
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Uploading image snapshot… ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.7/7.1 GB 0:00:00
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Uploading image snapshot… ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━ 2.6/7.1 GB 0:00:00
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Uploading image snapshot… ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━ 3.0/7.1 GB 0:00:00
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 7.1/7.1 GB 0:00:01
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Image saved, took 2.14s
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 7.1/7.1 GB 0:00:01
# ⠼ Creating objects...
#  Created mount /Users/marcolerma/GitHub/applied-llm-engineering/lectures/w
# Built image im-4A3eK4IC2ndUPHj2eRW2Aj in 79.57s
#
#
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 7.1/7.1 GB 0:00:01
# ⠼ Creating objects...
# ⠧ Creating objects...ma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Building image im-AKZC7eMm3wehUuLtYihH4y
# ⠏ Creating objects...
# ⠏ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
#
# => Step 0: FROM base
# ⠧ Creating objects...
# m🔨 Created mount /Users/marcolerma/GitHub/applied-llm-engineering/lectures/w
# => Step 1: ENV HF_HUB_CACHE=/cache
# ⠧ Creating objects...
# ⠏ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Saving image...
# ⠋ Creating objects...
# ⠹ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# Image saved, took 1.75s
# ⠹ Creating objects...
# m🔨 Created mount /Users/marcolerma/GitHub/applied-llm-engineering/lectures/w
# Built image im-AKZC7eMm3wehUuLtYihH4y in 2.66s
#
#
# ⠸ Creating objects...
# ⠼ Creating objects...marcolerma/GitHub/applied-llm-engineering/lectures/w
# └── 🔨 Created mount
#     /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# ⠇ Creating objects...
# ├── 🔨 Created mount
# │   /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# │   service2.py
# ⠏ Creating objects...
# ├── 🔨 Created mount
# │   /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# │   service2.py
# └── 🔨 Created function Pricer.*.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/marcolerma/GitHub/applied-llm-engineering/lectures/week-eight/pricer_
# │   service2.py
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 86.351s! 🎉
#
# View Deployment:
# https://modal.com/apps/marcolerma-1312/main/deployed/pricer-service

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote(text)
print(reply)
# Out:
# 110.0

# %%
reply = pricer.price.remote(text)
print(reply)
# Out:
# 110.0

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# The first time you run this modal class, it might take as much as 10 minutes to build.
# Subsequently it should be much faster.. 30 seconds if it needs to wake up, otherwise 2 seconds.
# If you want it to always be 2 seconds, you can keep the container from going to sleep by editing this constant in pricer_service2.py:
#
# `MIN_CONTAINERS = 0`
#
#
#
# Make it 1 to keep a container alive.
# But please note: this will eat up credits! Only do this if you are comfortable to have a process running continually.
#
# Alternatively, you can run this code and it will stay warm for 20 mins rather than 2 mins.
#
# ### Code to keep warm for 20 mins before cooling down:
#
# ```python
# import modal
# Pricer = modal.Cls.from_name("pricer-service", "Pricer")
# pricer = Pricer()
# pricer.update_autoscaler(scaledown_window=1200)
# ```
#
# ### Code to revert to keeping warm for only 2 mins
#
# ```python
# import modal
# Pricer = modal.Cls.from_name("pricer-service", "Pricer")
# pricer = Pricer()
# pricer.update_autoscaler(scaledown_window=120)
# ```

# %% [markdown]
# ## And now introducing our Agent class
#
# The agent preprocesses product descriptions using the model configured in `.env`.
#
# For this notebook, the configured model is OpenAI GPT-5 nano:
#
# ```
# PRICER_PREPROCESSOR_MODEL=openai/gpt-5-nano
# ```

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
# Out:
# INFO:root:[Specialist Agent] Specialist Agent is initializing - connecting to modal

# %%
agent.price("iPhone 10")
# Out:
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $350.00
# 350.0
